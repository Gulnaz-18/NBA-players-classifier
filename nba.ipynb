# %%
# !wget -O 2018-2019_NBA_Stats.csv https://uta.instructure.com/courses/61673/files/10505095/preview?verifier=1qoqyIxNj5MjnRrfNGQsUpWHAQs0TDZiyDLfTKps

import io
import pandas as pd
from google.colab import files

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

### You may need to import more modules based on what you want to use, 
### as long as they are from scikit-learn, Pandas, NumPy, or the Python 
### Standard Library.

### DON'T CHANGE LINES #16-#54

#Read from the csv file and return a Pandas DataFrame.
stats_file = '/content/2018-2019_NBA_Stats.csv'
nba = pd.read_csv(io.FileIO(stats_file))

print("Number of rows and number of columns:", nba.shape)
original_headers = list(nba.columns.values)
print("Column names:", original_headers)
print()

#"Position" is the class attribute/column we are predicting. 
class_column = 'Position'

#The dataset contains attributes such as player name and team name. 
#We know that they are not useful for classification and thus do not 
#include them as features. 
feature_columns = ['Games Played', 'Minutes Per Game',\
                   'Points Per Game', 'Total Rebounds Per Game',\
                   'Assists Per Game', 'Three Points Made Per Game',\
                   'Steals Per Game', 'Blocks Per Game', 'Turnovers Per Game']

#Pandas DataFrame allows you to select columns. 
#We use column selection to split the data into features and class. 
nba_feature = nba[feature_columns]
nba_class = nba[class_column]

print("First three rows")
print(nba[0:3])
print()
print("Feature columns, first three rows:")
print(nba_feature[0:3])
print()
print("Class column, first three rows:")
print(nba_class[0:3])
print()

#Split the dataset into training/test set.
train_feature, test_feature, train_class, test_class = \
    train_test_split(nba_feature, nba_class, stratify=nba_class, \
    train_size=0.75, test_size=0.25)

###DON'T CHANGE LINES #16-#54

###Our skeleton code uses KNN classification without tuning any paremeter. 
###You will need to replace line #66 by your method. You can replace it by as 
###many lines as you want, and you can choose to define functions to make your  
###code modularized. 

model = KNeighborsClassifier(n_neighbors=5)

###DON'T CHANGE LINES #67-#91

scores = cross_val_score(model, nba_feature, nba_class, cv=5)
print("Cross-validation scores: {}".format(scores))
print("Average cross-validation score: {:.2f}".format(scores.mean()))
print()
model.fit(train_feature, train_class)
print("Test set accuracy: {:.2f}".format(model.score(test_feature, test_class)))
print()
prediction = model.predict(test_feature)
print("Test set predictions:\n{}".format(prediction))
print()
print("Confusion matrix:")
print(pd.crosstab(test_class, prediction, rownames=['True'], colnames=['Predicted'], margins=True))
print()
print("Classification report:")
print(classification_report(test_class, prediction))

#Save the training and test sets into CSV files.
train_class_df = pd.DataFrame(train_class, columns=[class_column])     
train_data_df = pd.merge(train_class_df, train_feature, left_index=True, right_index=True)
train_data_df.to_csv('train_data.csv', float_format='%.3f', index=False)

temp_df = pd.DataFrame(test_class, columns=[class_column])
temp_df['Predicted Pos']=pd.Series(prediction, index=temp_df.index)
test_data_df = pd.merge(temp_df, test_feature, left_index=True, right_index=True)
test_data_df.to_csv('test_data.csv', float_format='%.3f', index=False)

###DON'T CHANGE LINES #67-#91
# Out:
# --2020-11-05 02:33:11--  https://uta.instructure.com/courses/61673/files/10505095/preview?verifier=1qoqyIxNj5MjnRrfNGQsUpWHAQs0TDZiyDLfTKps
# Resolving uta.instructure.com (uta.instructure.com)... 54.237.172.187, 50.17.80.246, 34.224.181.213
# Connecting to uta.instructure.com (uta.instructure.com)|54.237.172.187|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://a13430-10505095.cluster38.canvas-user-content.com/courses/13430~61673/files/13430~10505095/course%20files/public_files/2018-2019_NBA_stats.csv?download=1&inline=1&verifier=1qoqyIxNj5MjnRrfNGQsUpWHAQs0TDZiyDLfTKps [following]
# --2020-11-05 02:33:11--  https://a13430-10505095.cluster38.canvas-user-content.com/courses/13430~61673/files/13430~10505095/course%20files/public_files/2018-2019_NBA_stats.csv?download=1&inline=1&verifier=1qoqyIxNj5MjnRrfNGQsUpWHAQs0TDZiyDLfTKps
# Resolving a13430-10505095.cluster38.canvas-user-content.com (a13430-10505095.cluster38.canvas-user-content.com)... 54.172.77.166, 54.210.131.83, 34.199.144.100
# Connecting to a13430-10505095.cluster38.canvas-user-content.com (a13430-10505095.cluster38.canvas-user-content.com)|54.172.77.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://inst-fs-iad-prod.inscloudgate.net/files/6e6f867c-2ece-4a58-991b-c6c3ac682ada/2018-2019_NBA_stats.csv?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpYXQiOjE2MDQ1NDAwOTMsInVzZXJfaWQiOm51bGwsInJlc291cmNlIjoiL2ZpbGVzLzZlNmY4NjdjLTJlY2UtNGE1OC05OTFiLWM2YzNhYzY4MmFkYS8yMDE4LTIwMTlfTkJBX3N0YXRzLmNzdiIsImhvc3QiOm51bGwsImV4cCI6MTYwNDYyNjQ5M30.RmPbzl98-xOKzONjLvnYhO9zKLrSVrmCOLSLNby4LToGwqyej45eEfyCJ0jvXY3RJwkm4e0fLN4btz6n5JcyKQ [following]
# --2020-11-05 02:33:11--  https://inst-fs-iad-prod.inscloudgate.net/files/6e6f867c-2ece-4a58-991b-c6c3ac682ada/2018-2019_NBA_stats.csv?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpYXQiOjE2MDQ1NDAwOTMsInVzZXJfaWQiOm51bGwsInJlc291cmNlIjoiL2ZpbGVzLzZlNmY4NjdjLTJlY2UtNGE1OC05OTFiLWM2YzNhYzY4MmFkYS8yMDE4LTIwMTlfTkJBX3N0YXRzLmNzdiIsImhvc3QiOm51bGwsImV4cCI6MTYwNDYyNjQ5M30.RmPbzl98-xOKzONjLvnYhO9zKLrSVrmCOLSLNby4LToGwqyej45eEfyCJ0jvXY3RJwkm4e0fLN4btz6n5JcyKQ
# Resolving inst-fs-iad-prod.inscloudgate.net (inst-fs-iad-prod.inscloudgate.net)... 52.6.209.86, 34.239.67.222, 35.169.214.33, ...
# Connecting to inst-fs-iad-prod.inscloudgate.net (inst-fs-iad-prod.inscloudgate.net)|52.6.209.86|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn.inst-fs-iad-prod.inscloudgate.net/7b00f992-29d4-4a93-9809-7d3ef0246a42/2018-2019_NBA_stats.csv?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii83YjAwZjk5Mi0yOWQ0LTRhOTMtOTgwOS03ZDNlZjAyNDZhNDIvMjAxOC0yMDE5X05CQV9zdGF0cy5jc3YiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjpudWxsLCJpYXQiOjE2MDQ1NDAwOTMsImV4cCI6MTYwNDYyNjQ5M30.xMUSp9iYuOpe89gzBpcJt1cB3_o9jflFYHmqlCSy24Mpx5dahjZxLLnXioQL1NbOB4SFjPXZEMo5uDBq8i8xrQ&content_type=text%2Fcsv [following]
# --2020-11-05 02:33:12--  https://cdn.inst-fs-iad-prod.inscloudgate.net/7b00f992-29d4-4a93-9809-7d3ef0246a42/2018-2019_NBA_stats.csv?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii83YjAwZjk5Mi0yOWQ0LTRhOTMtOTgwOS03ZDNlZjAyNDZhNDIvMjAxOC0yMDE5X05CQV9zdGF0cy5jc3YiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjpudWxsLCJpYXQiOjE2MDQ1NDAwOTMsImV4cCI6MTYwNDYyNjQ5M30.xMUSp9iYuOpe89gzBpcJt1cB3_o9jflFYHmqlCSy24Mpx5dahjZxLLnXioQL1NbOB4SFjPXZEMo5uDBq8i8xrQ&content_type=text%2Fcsv
# Resolving cdn.inst-fs-iad-prod.inscloudgate.net (cdn.inst-fs-iad-prod.inscloudgate.net)... 13.226.49.59, 13.226.49.110, 13.226.49.44, ...
# Connecting to cdn.inst-fs-iad-prod.inscloudgate.net (cdn.inst-fs-iad-prod.inscloudgate.net)|13.226.49.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20605 (20K) [text/csv]
# Saving to: ‘2018-2019_NBA_Stats.csv’
#
# 2018-2019_NBA_Stats 100%[===================>]  20.12K  --.-KB/s    in 0.003s
#
# 2020-11-05 02:33:12 (6.94 MB/s) - ‘2018-2019_NBA_Stats.csv’ saved [20605/20605]
#
# Number of rows and number of columns: (300, 12)
# Column names: ['Player', 'Position', 'Team', 'Games Played', 'Minutes Per Game', 'Points Per Game', 'Total Rebounds Per Game', 'Assists Per Game', 'Three Points Made Per Game', 'Steals Per Game', 'Blocks Per Game', 'Turnovers Per Game']
#
# First three rows
#                   Player Position  ... Blocks Per Game  Turnovers Per Game
# 0           James Harden       SG  ...           0.742               4.532
# 1  Giannis Antetokounmpo       PF  ...           1.696               3.502
# 2          Stephen Curry       PG  ...           0.424               2.987
#
# [3 rows x 12 columns]
#
# Feature columns, first three rows:
#    Games Played  Minutes Per Game  ...  Blocks Per Game  Turnovers Per Game
# 0            78                36  ...            0.742               4.532
# 1            72                33  ...            1.696               3.502
# 2            76                35  ...            0.424               2.987
#
# [3 rows x 9 columns]
#
# Class column, first three rows:
# 0    SG
# 1    PF
# 2    PG
# Name: Position, dtype: object
#
# Cross-validation scores: [0.43333333 0.5        0.31666667 0.41666667 0.33333333]
# Average cross-validation score: 0.40
#
# Test set accuracy: 0.49
#
# Test set predictions:
# ['PF' 'PF' 'C' 'C' 'C' 'SF' 'PF' 'SF' 'SF' 'SF' 'PF' 'PF' 'SG' 'SF' 'SF'
#  'SG' 'PF' 'SF' 'SG' 'PG' 'SF' 'PF' 'SG' 'PF' 'PG' 'SF' 'SG' 'SG' 'PF'
#  'PG' 'SF' 'PF' 'PF' 'PF' 'C' 'SG' 'C' 'SG' 'C' 'PF' 'C' 'SG' 'PF' 'PG'
#  'SG' 'PF' 'PF' 'PG' 'PG' 'C' 'C' 'SG' 'PG' 'PG' 'SG' 'SG' 'PF' 'C' 'PF'
#  'C' 'PG' 'SF' 'SF' 'SF' 'SF' 'PF' 'PF' 'C' 'PG' 'C' 'PG' 'C' 'SF' 'SG'
#  'SF']
#
# Confusion matrix:
# Predicted   C  PF  PG  SF  SG  All
# True
# C          10   4   0   0   0   14
# PF          2   8   0   5   1   16
# PG          0   1   7   3   4   15
# SF          1   5   2   5   2   15
# SG          1   2   2   3   7   15
# All        14  20  11  16  14   75
#
# Classification report:
#               precision    recall  f1-score   support
#
#            C       0.71      0.71      0.71        14
#           PF       0.40      0.50      0.44        16
#           PG       0.64      0.47      0.54        15
#           SF       0.31      0.33      0.32        15
#           SG       0.50      0.47      0.48        15
#
#     accuracy                           0.49        75
#    macro avg       0.51      0.50      0.50        75
# weighted avg       0.51      0.49      0.50        75
