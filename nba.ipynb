# %% [markdown]
# <a href="https://colab.research.google.com/github/Gulnaz-18/nba/blob/main/nba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O 2018-2019_NBA_Stats.csv https://uta.instructure.com/courses/61673/files/10505095/preview?verifier=1qoqyIxNj5MjnRrfNGQsUpWHAQs0TDZiyDLfTKps
import io
import pandas as pd
from google.colab import files

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn import svm





### You may need to import more modules based on what you want to use, 
### as long as they are from scikit-learn, Pandas, NumPy, or the Python 
### Standard Library.

### DON'T CHANGE LINES #16-#54

#Read from the csv file and return a Pandas DataFrame.
stats_file = '/content/2018-2019_NBA_Stats.csv'
nba = pd.read_csv(io.FileIO(stats_file))

print("Number of rows and number of columns:", nba.shape)
original_headers = list(nba.columns.values)
print("Column names:", original_headers)
print()

#"Position" is the class attribute/column we are predicting. 
class_column = 'Position'

#The dataset contains attributes such as player name and team name. 
#We know that they are not useful for classification and thus do not 
#include them as features. 
feature_columns = ['Games Played', 'Minutes Per Game',\
                   'Points Per Game', 'Total Rebounds Per Game',\
                   'Assists Per Game', 'Three Points Made Per Game',\
                   'Steals Per Game', 'Blocks Per Game', 'Turnovers Per Game']

#Pandas DataFrame allows you to select columns. 
#We use column selection to split the data into features and class. 
nba_feature = nba[feature_columns]
nba_class = nba[class_column]

print("First three rows")
print(nba[0:3])
print()
print("Feature columns, first three rows:")
print(nba_feature[0:3])
print()
print("Class column, first three rows:")
print(nba_class[0:3])
print()

#Split the dataset into training/test set.
train_feature, test_feature, train_class, test_class = \
    train_test_split(nba_feature, nba_class, stratify=nba_class, \
    train_size=0.75, test_size=0.25)

###DON'T CHANGE LINES #16-#54

###Our skeleton code uses KNN classification without tuning any paremeter. 
###You will need to replace line #66 by your method. You can replace it by as 
###many lines as you want, and you can choose to define functions to make your  
###code modularized. 

#applying Support Vector Machines method 
model = svm.SVC(C=1, kernel='linear', gamma='auto')

#other models that I have implemented 
#model = LinearSVC(max_iter=5000)
#model = GaussianNB()
#model = DecisionTreeClassifier(criterion = 'entropy',max_depth=5)
#model = KNeighborsClassifier(n_neighbors=5)
#model = RandomForestClassifier(n_estimators=100, criterion="entropy", max_depth=4)

###DON'T CHANGE LINES #67-#91

scores = cross_val_score(model,nba_feature, nba_class, cv=5)
print("Cross-validation scores: {}".format(scores))
print("\nAverage cross-validation score: {:.2f}".format(scores.mean()))
print()
model.fit(train_feature, train_class)
print("Test set accuracy: {:.2f}".format(model.score(test_feature, test_class)))
print()
prediction = model.predict(test_feature)
print("Test set predictions:\n{}".format(prediction))
print()
print("Confusion matrix:")
print(pd.crosstab(test_class, prediction, rownames=['True'], colnames=['Predicted'], margins=True))
print()
print("Classification report:")
print(classification_report(test_class, prediction))

#Save the training and test sets into CSV files.
train_class_df = pd.DataFrame(train_class, columns=[class_column])     
train_data_df = pd.merge(train_class_df, train_feature, left_index=True, right_index=True)
train_data_df.to_csv('train_data.csv', float_format='%.3f', index=False)

temp_df = pd.DataFrame(test_class, columns=[class_column])
temp_df['Predicted Pos']=pd.Series(prediction, index=temp_df.index)
test_data_df = pd.merge(temp_df, test_feature, left_index=True, right_index=True)
test_data_df.to_csv('test_data.csv', float_format='%.3f', index=False)
print()
#print("Feature importances:\n{}".format(model.feature_importances_))



###DON'T CHANGE LINES #67-#91
# Out:
# --2020-11-19 00:03:21--  https://uta.instructure.com/courses/61673/files/10505095/preview?verifier=1qoqyIxNj5MjnRrfNGQsUpWHAQs0TDZiyDLfTKps
# Resolving uta.instructure.com (uta.instructure.com)... 52.21.165.220, 52.202.2.19, 34.224.181.213
# Connecting to uta.instructure.com (uta.instructure.com)|52.21.165.220|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://a13430-10505095.cluster38.canvas-user-content.com/courses/13430~61673/files/13430~10505095/course%20files/public_files/2018-2019_NBA_stats.csv?download=1&inline=1&verifier=1qoqyIxNj5MjnRrfNGQsUpWHAQs0TDZiyDLfTKps [following]
# --2020-11-19 00:03:22--  https://a13430-10505095.cluster38.canvas-user-content.com/courses/13430~61673/files/13430~10505095/course%20files/public_files/2018-2019_NBA_stats.csv?download=1&inline=1&verifier=1qoqyIxNj5MjnRrfNGQsUpWHAQs0TDZiyDLfTKps
# Resolving a13430-10505095.cluster38.canvas-user-content.com (a13430-10505095.cluster38.canvas-user-content.com)... 52.22.206.196, 52.4.46.105, 3.230.70.68
# Connecting to a13430-10505095.cluster38.canvas-user-content.com (a13430-10505095.cluster38.canvas-user-content.com)|52.22.206.196|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://inst-fs-iad-prod.inscloudgate.net/files/6e6f867c-2ece-4a58-991b-c6c3ac682ada/2018-2019_NBA_stats.csv?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpYXQiOjE2MDU3MDk5NjYsInVzZXJfaWQiOm51bGwsInJlc291cmNlIjoiL2ZpbGVzLzZlNmY4NjdjLTJlY2UtNGE1OC05OTFiLWM2YzNhYzY4MmFkYS8yMDE4LTIwMTlfTkJBX3N0YXRzLmNzdiIsImhvc3QiOm51bGwsImV4cCI6MTYwNTc5NjM2Nn0.j-kcL9Ki9aib5MzKUI7Ilnhy1WSldPs4NLkq8WVG0ezafz3JGVOxNnAac3b4FlwcfkvU783H_TDN5kraxdLfsA [following]
# --2020-11-19 00:03:22--  https://inst-fs-iad-prod.inscloudgate.net/files/6e6f867c-2ece-4a58-991b-c6c3ac682ada/2018-2019_NBA_stats.csv?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpYXQiOjE2MDU3MDk5NjYsInVzZXJfaWQiOm51bGwsInJlc291cmNlIjoiL2ZpbGVzLzZlNmY4NjdjLTJlY2UtNGE1OC05OTFiLWM2YzNhYzY4MmFkYS8yMDE4LTIwMTlfTkJBX3N0YXRzLmNzdiIsImhvc3QiOm51bGwsImV4cCI6MTYwNTc5NjM2Nn0.j-kcL9Ki9aib5MzKUI7Ilnhy1WSldPs4NLkq8WVG0ezafz3JGVOxNnAac3b4FlwcfkvU783H_TDN5kraxdLfsA
# Resolving inst-fs-iad-prod.inscloudgate.net (inst-fs-iad-prod.inscloudgate.net)... 3.228.76.20, 52.72.36.204, 34.233.102.102, ...
# Connecting to inst-fs-iad-prod.inscloudgate.net (inst-fs-iad-prod.inscloudgate.net)|3.228.76.20|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn.inst-fs-iad-prod.inscloudgate.net/7b00f992-29d4-4a93-9809-7d3ef0246a42/2018-2019_NBA_stats.csv?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii83YjAwZjk5Mi0yOWQ0LTRhOTMtOTgwOS03ZDNlZjAyNDZhNDIvMjAxOC0yMDE5X05CQV9zdGF0cy5jc3YiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjpudWxsLCJpYXQiOjE2MDU3MDk5NjYsImV4cCI6MTYwNTc5NjM2Nn0.xJ6swv6ZkuxhObnm7LwhLn_bMXqbQhjagVf5UsHY7XzW0RMuTdrXm04oCa-OA6k4AeNDYXQ-QQ3VQXlU78fTxQ&content_type=text%2Fcsv [following]
# --2020-11-19 00:03:22--  https://cdn.inst-fs-iad-prod.inscloudgate.net/7b00f992-29d4-4a93-9809-7d3ef0246a42/2018-2019_NBA_stats.csv?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii83YjAwZjk5Mi0yOWQ0LTRhOTMtOTgwOS03ZDNlZjAyNDZhNDIvMjAxOC0yMDE5X05CQV9zdGF0cy5jc3YiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjpudWxsLCJpYXQiOjE2MDU3MDk5NjYsImV4cCI6MTYwNTc5NjM2Nn0.xJ6swv6ZkuxhObnm7LwhLn_bMXqbQhjagVf5UsHY7XzW0RMuTdrXm04oCa-OA6k4AeNDYXQ-QQ3VQXlU78fTxQ&content_type=text%2Fcsv
# Resolving cdn.inst-fs-iad-prod.inscloudgate.net (cdn.inst-fs-iad-prod.inscloudgate.net)... 13.224.10.69, 13.224.10.41, 13.224.10.94, ...
# Connecting to cdn.inst-fs-iad-prod.inscloudgate.net (cdn.inst-fs-iad-prod.inscloudgate.net)|13.224.10.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20605 (20K) [text/csv]
# Saving to: ‘2018-2019_NBA_Stats.csv’
#
# 2018-2019_NBA_Stats 100%[===================>]  20.12K  --.-KB/s    in 0s
#
# 2020-11-19 00:03:23 (166 MB/s) - ‘2018-2019_NBA_Stats.csv’ saved [20605/20605]
#
# Number of rows and number of columns: (300, 12)
# Column names: ['Player', 'Position', 'Team', 'Games Played', 'Minutes Per Game', 'Points Per Game', 'Total Rebounds Per Game', 'Assists Per Game', 'Three Points Made Per Game', 'Steals Per Game', 'Blocks Per Game', 'Turnovers Per Game']
#
# First three rows
#                   Player Position  ... Blocks Per Game  Turnovers Per Game
# 0           James Harden       SG  ...           0.742               4.532
# 1  Giannis Antetokounmpo       PF  ...           1.696               3.502
# 2          Stephen Curry       PG  ...           0.424               2.987
#
# [3 rows x 12 columns]
#
# Feature columns, first three rows:
#    Games Played  Minutes Per Game  ...  Blocks Per Game  Turnovers Per Game
# 0            78                36  ...            0.742               4.532
# 1            72                33  ...            1.696               3.502
# 2            76                35  ...            0.424               2.987
#
# [3 rows x 9 columns]
#
# Class column, first three rows:
# 0    SG
# 1    PF
# 2    PG
# Name: Position, dtype: object
#
# Cross-validation scores: [0.5        0.58333333 0.71666667 0.66666667 0.51666667]
#
# Average cross-validation score: 0.60
#
# Test set accuracy: 0.65
#
# Test set predictions:
# ['PG' 'SF' 'C' 'SF' 'C' 'SG' 'SF' 'PG' 'C' 'SF' 'SF' 'C' 'PF' 'C' 'C' 'SG'
#  'PF' 'SF' 'C' 'SF' 'PG' 'C' 'PF' 'C' 'PG' 'SG' 'SG' 'C' 'C' 'SG' 'SG'
#  'PF' 'PF' 'PF' 'C' 'SG' 'C' 'SG' 'PF' 'SG' 'SG' 'SF' 'SG' 'PG' 'SF' 'SF'
#  'PG' 'SF' 'SG' 'PG' 'SF' 'PG' 'PF' 'SG' 'SF' 'PF' 'PF' 'SF' 'PF' 'SG'
#  'PG' 'SF' 'C' 'C' 'PG' 'PG' 'SF' 'SG' 'SG' 'SF' 'SF' 'C' 'PG' 'C' 'C']
#
# Confusion matrix:
# Predicted   C  PF  PG  SF  SG  All
# True
# C          12   2   0   0   0   14
# PF          6   7   0   3   0   16
# PG          0   1  11   1   2   15
# SF          0   0   0  10   5   15
# SG          0   1   1   4   9   15
# All        18  11  12  18  16   75
#
# Classification report:
#               precision    recall  f1-score   support
#
#            C       0.67      0.86      0.75        14
#           PF       0.64      0.44      0.52        16
#           PG       0.92      0.73      0.81        15
#           SF       0.56      0.67      0.61        15
#           SG       0.56      0.60      0.58        15
#
#     accuracy                           0.65        75
#    macro avg       0.67      0.66      0.65        75
# weighted avg       0.67      0.65      0.65        75
